# %% [markdown]
# ## List
# ## What is list and why we use it?
# ### List is collection of hetrogenous data type which is mutable and has indexing.
# ### If we want to store multiple values in a single variable and can be modify and access easily with their index then we have to create a list.
#
# ### Example :
# #### Suppose you want to store names of your classmates in normal approach you will create name variable and assign their name to it but in this condition the number of variable will be equal to number of classmates. It is too difficult to remember them.
# #### But with the list capability you can store all names of your classmates in single variable and can acess with single name with indexing.
#
# ### Properties of list
# #### 1. Mutable --> can be modified after creation
# #### 2. Indexed --> We can acess the value by index
# #### 3. Hetrogenous --> Can store multiple different data types
# #### 4. Elements are seperated by ,

# %%
# Method 1 
a = [1,25,'chintu', 98, [200,500]]
print(a)
# Out:
# [1, 25, 'chintu', 98, [200, 500]]

# %%
# Method 2 
a = list((25, 96, 14, 'A')) # constructor method
print(a)
# Out:
# [25, 96, 14, 'A']

# %%
a = this
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = this
#
# NameError: name 'this' is not defined

# %%
this  = 2100
a = this
a
# Out:
# 2100

# %%
# list has index and  slicing

# %%
fruits = ['apple','mango', 'orange', 'pineapple', 'kiwi', 'chiku' ]
print(fruits)
print(type(fruits))
# Out:
# ['apple', 'mango', 'orange', 'pineapple', 'kiwi', 'chiku']
# <class 'list'>

# %%
print(fruits[2])
# Out:
# orange

# %%
fruits[2]= 'litchi'
fruits
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']

# %%
# Slicing
print(fruits)
print(fruits[:3])
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']
# ['apple', 'mango', 'litchi']

# %%
# Slicing
print(fruits)
print(fruits[4:])
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']
# ['kiwi', 'chiku']

# %%
# Slicing with step size
print(fruits)
print(fruits[::2])
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']
# ['apple', 'litchi', 'kiwi']

# %%
# Slicing with step size
print(fruits)
print(fruits[2:2])
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']
# []

# %%
# Slicing with step size
print(fruits)
print(fruits[2:0])
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']
# []

# %%
# Slicing with step size
print(fruits)
print(fruits[2:-1])
# Out:
# ['apple', 'mango', 'litchi', 'pineapple', 'kiwi', 'chiku']
# ['litchi', 'pineapple', 'kiwi']

# %%
dict1 = {'name':"chintu", 'lname': 'Chaure'}
names = list(dict1)
print(type(names))
print(names)
# Out:
# <class 'list'>
# ['name', 'lname']

# %%
# Add new element or item in list
# Method 1
# append
print(list.append.__doc__)
# Out:
# Append object to the end of the list.

# %%
# Example 
li = ['Chintu', 'sakshi']
li.append('Rahul')
print(li)
# Out:
# ['Chintu', 'sakshi', 'Rahul']

# %%
# insert Method
print(list.insert.__doc__)
# Out:
# Insert object before index.

# %%
# Example 
li = ['Chintu', 'sakshi']
li.insert(1,'Rahul')
print(li)
# Out:
# ['Chintu', 'Rahul', 'sakshi']

# %%
# Example 
li = ['Chintu', 'sakshi', 'Mohan']
li.insert(2,'Rahul')
print(li)
# Out:
# ['Chintu', 'sakshi', 'Rahul', 'Mohan']

# %%
# Extend
print(list.extend.__doc__)
# Out:
# Extend list by appending elements from the iterable.

# %%
li = ['Chintu', 'sakshi']
rs = ('komal', 'rohan', 'sohan')
li.extend(rs)
print(li)
# Out:
# ['Chintu', 'sakshi', 'komal', 'rohan', 'sohan']

# %%
li[1] = 'Palak'
li
# Out:
# ['Chintu', 'Palak', 'komal', 'rohan', 'sohan']

# %%
# copy
l1 = ['Chintu', 'sakshi']
l2 = l1 # it will resign the refrence not make the copy
print(l1)
print(l2)
# Out:
# ['Chintu', 'sakshi']
# ['Chintu', 'sakshi']

# %%
l2.append('New_Item')

# %%
print(l1)
# Out:
# ['Chintu', 'sakshi', 'New_Item']

# %%
 l1 = ['Chintu', 'sakshi']
l3 = l1.copy() # it will resign the refrence not make the copy
print(l1)
print(l3)
# Out:
# ['Chintu', 'sakshi']
# ['Chintu', 'sakshi']

# %%
l2.insert(0,'Mohan')
print(l1)
# Out:
# ['Chintu', 'sakshi']

# %%
print(l2)
# Out:
# ['Mohan', 'Chintu', 'sakshi', 'New_Item']

# %%
li = ['Mohan', 'Chintu', 'sakshi']
a = li.pop() # it remove the last element of list if index not given 
print(a)
print(li)
# Out:
# sakshi
# ['Mohan', 'Chintu']

# %%
li = ['Mohan', 'Chintu', 'sakshi']
a = li.pop(1) # it remove value of given index 
print(a)
print(li)
# Out:
# Chintu
# ['Mohan', 'sakshi']

# %%
li = ['Mohan', 'Chintu', 'sakshi']
li.remove('Mohan') # it remove given element
print(li)
# Out:
# ['Chintu', 'sakshi']

# %%
li = ['Mohan', 'Chintu', 'sakshi']
li.remove('Sohan') # it remove given element
print(li)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 li = ['Mohan', 'Chintu', 'sakshi']
# ----> 2 li.remove('Sohan') # it remove given element
#       3 print(li)
#
# ValueError: list.remove(x): x not in list

# %%
li = ['Mohan', 'Chintu', 'sakshi']
li.clear() # it remove all element
print(li)
# Out:
# []

# %%
# del
li = ['Mohan', 'Chintu', 'sakshi']
del li # it remove the variable 
print(li)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 4
#       2 li = ['Mohan', 'Chintu', 'sakshi']
#       3 del li# it remove all element
# ----> 4 print(li)
#
# NameError: name 'li' is not defined

# %%
li = ['Mohan', 'Chintu', 'sakshi']
li.sort() # it sort all the element in increasing order as per ASCII value
print(li)
# Out:
# ['Chintu', 'Mohan', 'sakshi']

# %%
li = ['mohan', 'ahintu', 'Sakshi']
li.sort() # it remove all element
print(li)
# Out:
# ['Sakshi', 'ahintu', 'mohan']

# %%
li = [1000, 12, 580, 98, 1]
li.sort()
print(li)
# Out:
# [1, 12, 98, 580, 1000]

# %%
li = [1000, 12, 580, 98, 1]
li.sort(reverse = True)
print(li)
# Out:
# [1000, 580, 98, 12, 1]

# %%
li = ['Ram', 'Chintu', 'Mohan']
li.reverse()
print(li)
# Out:
# ['Mohan', 'Chintu', 'Ram']

# %%
li = ['Ram', 'Chintu', 'Mohan']
li.sort()
print(li)
# Out:
# ['Chintu', 'Mohan', 'Ram']

# %%
li = ['Ram', 'Chintu', 'Mohan']
li.sort(reverse = True)
print(li)
# Out:
# ['Ram', 'Mohan', 'Chintu']

# %%
li = ['Ram', 'Chintu','IceCream', 'Mohan', 'Sita','z' ]
li.sort(key = len)
print(li)
# Out:
# ['z', 'Ram', 'Sita', 'Mohan', 'Chintu', 'IceCream']

# %%
# Loop on list
li = [12,36,5,'ram', 'Kavita', 15.6, 'Savita']
